# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import names
import sklearn

# %% [markdown]
# ### Training a Naive Bayes Classifier to classify gender of names

# %%
def gender_features(word):
    return {'suffix1': word[-1:],
            'suffix2': word[-2:]}

# %%
import random
labeled_names = ([(name, 'male') for name in names.words('male.txt')]+
             [(name, 'female') for name in names.words('female.txt')])
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features(n), gender) 
               for (n, gender) in labeled_names]

classifier = nltk.NaiveBayesClassifier.train(featuresets)

# %%
#test on a new name
classifier.classify(gender_features('Trinity'))
# Out:
# 'female'

# %% [markdown]
# ### Use Classifier to Classify Names in Credits Dataset

# %%
credits = pd.read_csv('data/credits.csv')
credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
# credits['gender'] = classifier.classify(gender_features(credits['name'].split()[0]))
credits['gender'] = credits['name'].apply(lambda x : classifier.classify(gender_features(x.split()[0])))

# %%
credits.head(10)
# Out:
#    person_id       id             name                      character   role  \
# 0       3748  tm84618   Robert De Niro                  Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster                  Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                            Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel        Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                          Betsy  ACTOR
# 5      32267  tm84618      Peter Boyle                         Wizard  ACTOR
# 6     519612  tm84618   Leonard Harris      Senator Charles Palantine  ACTOR
# 7      29068  tm84618   Diahnne Abbott                Concession Girl  ACTOR
# 8     519613  tm84618      Gino Ardito             Policeman at Rally  ACTOR
# 9       3308  tm84618  Martin Scorsese  Passenger Watching Silhouette  ACTOR
#
#    gender
# 0    male
# 1  female
# 2    male
# 3    male
# 4    male
# 5    male
# 6    male
# 7  female
# 8    male
# 9    male

# %% [markdown]
# ### Use Classifier on titles_and_credits

# %%
titles_and_credits = pd.read_csv('data/titles_and_credits.csv')
titles_and_credits.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       id        title   type  \
# 0           0             1  tm84618  Taxi Driver  MOVIE
# 1           1             1  tm84618  Taxi Driver  MOVIE
# 2           2             1  tm84618  Taxi Driver  MOVIE
# 3           3             1  tm84618  Taxi Driver  MOVIE
# 4           4             1  tm84618  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres  ... seasons    imdb_id  \
# 0                 R      114  ['drama', 'crime']  ...     NaN  tt0075314
# 1                 R      114  ['drama', 'crime']  ...     NaN  tt0075314
# 2                 R      114  ['drama', 'crime']  ...     NaN  tt0075314
# 3                 R      114  ['drama', 'crime']  ...     NaN  tt0075314
# 4                 R      114  ['drama', 'crime']  ...     NaN  tt0075314
#
#   imdb_score  imdb_votes  tmdb_popularity  tmdb_score  person_id  \
# 0        8.2    808582.0           40.965       8.179       3748
# 1        8.2    808582.0           40.965       8.179      14658
# 2        8.2    808582.0           40.965       8.179       7064
# 3        8.2    808582.0           40.965       8.179       3739
# 4        8.2    808582.0           40.965       8.179      48933
#
#               name                character   role
# 0   Robert De Niro            Travis Bickle  ACTOR
# 1     Jodie Foster            Iris Steensma  ACTOR
# 2    Albert Brooks                      Tom  ACTOR
# 3    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4  Cybill Shepherd                    Betsy  ACTOR
#
# [5 rows x 21 columns]

# %%
titles_and_credits['gender'] = titles_and_credits['name'].apply(
    lambda x : classifier.classify(gender_features(x.split()[0])))

# %%
titles_and_credits.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1       id        title   type  \
# 0           0             1  tm84618  Taxi Driver  MOVIE
# 1           1             1  tm84618  Taxi Driver  MOVIE
# 2           2             1  tm84618  Taxi Driver  MOVIE
# 3           3             1  tm84618  Taxi Driver  MOVIE
# 4           4             1  tm84618  Taxi Driver  MOVIE
# 5           5             1  tm84618  Taxi Driver  MOVIE
# 6           6             1  tm84618  Taxi Driver  MOVIE
# 7           7             1  tm84618  Taxi Driver  MOVIE
# 8           8             1  tm84618  Taxi Driver  MOVIE
# 9           9             1  tm84618  Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
# 5  A mentally unstable Vietnam War veteran works ...          1976
# 6  A mentally unstable Vietnam War veteran works ...          1976
# 7  A mentally unstable Vietnam War veteran works ...          1976
# 8  A mentally unstable Vietnam War veteran works ...          1976
# 9  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres  ...    imdb_id  imdb_score  \
# 0                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 1                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 2                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 3                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 4                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 5                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 6                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 7                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 8                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
# 9                 R      114  ['drama', 'crime']  ...  tt0075314         8.2
#
#   imdb_votes  tmdb_popularity  tmdb_score  person_id             name  \
# 0   808582.0           40.965       8.179       3748   Robert De Niro
# 1   808582.0           40.965       8.179      14658     Jodie Foster
# 2   808582.0           40.965       8.179       7064    Albert Brooks
# 3   808582.0           40.965       8.179       3739    Harvey Keitel
# 4   808582.0           40.965       8.179      48933  Cybill Shepherd
# 5   808582.0           40.965       8.179      32267      Peter Boyle
# 6   808582.0           40.965       8.179     519612   Leonard Harris
# 7   808582.0           40.965       8.179      29068   Diahnne Abbott
# 8   808582.0           40.965       8.179     519613      Gino Ardito
# 9   808582.0           40.965       8.179       3308  Martin Scorsese
#
#                        character   role  gender
# 0                  Travis Bickle  ACTOR    male
# 1                  Iris Steensma  ACTOR  female
# 2                            Tom  ACTOR    male
# 3        Matthew 'Sport' Higgins  ACTOR    male
# 4                          Betsy  ACTOR    male
# 5                         Wizard  ACTOR    male
# 6      Senator Charles Palantine  ACTOR    male
# 7                Concession Girl  ACTOR  female
# 8             Policeman at Rally  ACTOR    male
# 9  Passenger Watching Silhouette  ACTOR    male
#
# [10 rows x 22 columns]

# %% [markdown]
# ### Gender Proportion vs Popularity of Titles

# %%
#groupby title and calculate proportion of female names - by doing onehotencoding of gender, then take avg of male and female
#for each title, create a separate observation for every genre that is listed
#scatterplot of %female vs popularity

# %%
titles_and_credits.groupby('id')['gender'].count()
# Out:
# id
# tm1000037    14
# tm1000147    10
# tm100015     25
# tm1000185    21
# tm100027     11
#              ..
# ts97584       2
# ts9794        1
# ts98252      11
# ts98316       1
# ts987         4
# Name: gender, Length: 5208, dtype: int64
